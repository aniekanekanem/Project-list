# %% [markdown]
# ﻿1. Project description: Product usage analysis report for Bellabeat
#
# Aim of project:  To help Bellabeat analyze how customers engage with non-Bellabeat products and how these customer behaviours could be applied to the Bellabeat product (Leaf Product).
#
# Client: Bellabeat
#
# Link: [Bellabeat Product analysis report](https://github.com/aniekanekanem/Bellabeat-Product-Analysis-Case-Study/blob/main/bellabeat-product-analysis-case-study-i%20(2).ipynb)
#
#
# 2. Project description: Gathering descriptive statistics to solve business problems
#
# Aim of project: The aim of this three in one project is to gather descriptive statistics of a built dataframe for the purpose of addressing a business challenge.
#
# Clients: Automatidata, TikTok, and Waze
#
# Links: [Descriptive statistics for business operation](https://github.com/aniekanekanem/Descriptive-stats-report-for-business-solutions/blob/main/descriptive-stats-report-for-business-solutions.ipynb)
#
#
#
# 3. Project description: Using visualizations to solve business problems
#
# Aim of project: The aim of this three in one project is to gather inference from visualization reports for the purpose of addressing a business challenge.
#
# Clients: Automatidata, TikTok, and Waze
#
# Links: [Visualization report for business operation](https://github.com/aniekanekanem/Visualization-report-for-business-operation/blob/main/visualization-report-for-busines-solutions.ipynb)
#
#
#
# 4. Project description: Using statistical testing to solve business problems
#
# Aim of project: The aim of this three in one project is to use statistical testing methods in studying the relationship among variables of a dataset which can be used to make inference for addressing a business challenge.
#
# Clients: Automatidata, TikTok, and Waze
#
# Links: [Statistical testing report for business operation](https://github.com/aniekanekanem/Statistical-testing-report-for-business-operation/blob/main/statistical-testing-report-for-business-solutions.ipynb)
#
#
# 5. Project description: Dashboard design using Business Intelligence documents (This one does not have any coding activities involved, it is just some series of documents only)
#
# Aim of project: This project is a three in one project comprising of steps processes derived from the Stakeholder requirements document, the project requirements document, and the strategy document used to design a dashboard that summarizes key insights that addresses the respective business challenges which will be used by data analyst or other data professionals in constructing the dashboard and finally being used by primary contacts for study, observation, investigation, and making informed business decisions.
#
# Clients: Cyclistic, MarkIT, and Google Fiber
#
# Links: [BI documents link](https://github.com/aniekanekanem/BI-documents-for-dashboard-design-and-construction/blob/main/business-intelligence-project-summary.ipynb)
